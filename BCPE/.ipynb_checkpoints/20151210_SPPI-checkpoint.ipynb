# %%
#imports
from __future__ import print_function
import pyart
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import numpy as np
from time import time
import os
from netCDF4 import num2date, date2num

# %%
fn  = '/home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163235.h5'
#Since the names in the HDF5 file are non-standard we use file_field_names = True
myradar = pyart.aux_io.read_odim_h5(fn, file_field_names=True)

# %%
lat_lines = np.arange(-27.5,-28.5,-.1)
lon_lines = np.arange(152.5, 153.5, .1)
my_display = pyart.graph.RadarMapDisplay(myradar)
my_display.azimuths=np.linspace(120,270,346)

# %%
f = plt.figure(figsize=[18,18])
plt.subplot(2,1,1)
my_display.plot_ppi_map('DBZH', vmin=0, vmax=50, 
                        lat_lines = lat_lines, lon_lines = lon_lines,
                        max_lat = -27.95, min_lat =-28.1, min_lon = 152.8, max_lon = 153.1,
                       cmap = pyart.graph.cm.NWSRef)
my_display.plot_point( 152.983333, -27.983333,
               label_text = 'Beaudesert', 
               label_offset=[.005,.005], symbol = 'bo' )
ax = plt.gca()
plt.subplot(2,1,2)
my_display.plot_ppi_map('VRADH', vmin=-25, vmax=25, 
                        lat_lines = lat_lines, lon_lines = lon_lines,
                        max_lat = -27.95, min_lat =-28.1, min_lon = 152.8, max_lon = 153.1,
                       cmap = pyart.graph.cm.EWilson17)
my_display.plot_point( 152.983333, -27.983333,
               label_text = 'Beaudesert', 
               label_offset=[.005,.005], symbol = 'bo' )
ax = plt.gca()

# %%
dirr = '/home/meso/temp/h5_20151210/'
fls = os.listdir(dirr)
fls.sort()

# %%
i = 0
for fl in fls:
    try:
        print('doing ', dirr+ fl)
        myradar = pyart.aux_io.read_odim_h5(dirr+ fl, file_field_names=True)
        
        lat_lines = np.arange(-27.5,-28.5,-.1)
        lon_lines = np.arange(152.5, 153.5, .1)
        my_display = pyart.graph.RadarMapDisplay(myradar)
        my_display.azimuths=np.linspace(120,270,346)
        
        f = plt.figure(figsize=[18,18])
        plt.subplot(2,1,1)
        my_display.plot_ppi_map('DBZH', vmin=0, vmax=50, 
                                lat_lines = lat_lines, lon_lines = lon_lines,
                                max_lat = -27.95, min_lat =-28.1, min_lon = 152.8, max_lon = 153.1,
                                cmap = pyart.graph.cm.NWSRef)
        
        my_display.plot_point( 152.983333, -27.983333,
               label_text = 'Beaudesert', 
               label_offset=[.005,.005], symbol = 'bo' )
        
        ax = plt.gca()
        plt.subplot(2,1,2)
        my_display.plot_ppi_map('VRADH', vmin=-25., vmax=25., 
                                lat_lines = lat_lines, lon_lines = lon_lines,
                                max_lat = -27.95, min_lat =-28.1, min_lon = 152.8, max_lon = 153.1,
                                cmap = pyart.graph.cm.EWilson17, colorbar_label = 'Radial Velocity (m/s)')
        
        my_display.plot_point( 152.983333, -27.983333,
               label_text = 'Beaudesert', 
               label_offset=[.005,.005], symbol = 'bo' )
        
        ax = plt.gca()
        plt.savefig('/home/meso/temp/images_20151210/ftorn_%03.0f.png' %i, dpi=50)
        plt.close()
        i = i +1
    except:
        pass
# Out:
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162453.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162502.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162511.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162521.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162530.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162539.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162548.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162558.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162607.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162616.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162625.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162635.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162644.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162653.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162702.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162711.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162721.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162730.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162739.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162748.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162758.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162807.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162816.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162825.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162835.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162844.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162853.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162902.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162912.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162921.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162930.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162939.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162949.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_162958.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163007.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163016.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163026.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163035.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163044.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163053.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163103.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163112.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163121.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163130.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163139.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163149.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163158.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163207.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163216.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163226.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163235.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163244.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163253.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163303.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163312.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163321.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163330.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163340.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163349.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163358.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163407.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163417.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163426.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163435.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163444.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163454.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163503.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163512.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163521.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163531.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163540.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163549.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163558.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163607.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163617.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163626.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163635.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163644.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163654.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163703.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163712.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163721.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163731.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163740.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163749.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163758.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163808.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163817.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163826.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163835.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163845.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163854.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163903.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163912.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163922.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163931.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163940.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163949.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_163958.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164008.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164017.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164026.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164035.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164045.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164054.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164103.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164112.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164122.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164131.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164140.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164149.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164159.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164208.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164217.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164226.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164236.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164245.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164254.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164303.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164313.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164322.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164331.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164340.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164350.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164359.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164408.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164417.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164426.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164436.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164445.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164454.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164503.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164513.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164522.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164531.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164540.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164550.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164559.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164608.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164617.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164627.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164636.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164645.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164654.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164704.h5
# doing  /home/meso/temp/h5_20151210/uq-xpol_sppi_20151210_164713.h5
# doing
